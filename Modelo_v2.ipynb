# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from matplotlib import pyplot as plt

# %%
dataset=pd.read_csv("proyecto_pre_procesado.csv",sep=";")
dataset
# Out:
#        PC   PMg    PP      PS     Psi   Pti   PNb   PCr     PBr   Pal  PV  \
# 0   235.0  1.23  21.0  0.0079    0.10  11.0   5.0  0.04  0.0004  42.0   5
# 1   242.0  1.22  14.0  0.0047    0.10  11.0  11.0  0.02  0.0005  41.0   2
# 2   234.0  1.24  19.0  0.0058    0.10  11.0   1.0  0.04  0.0005  44.0   4
# 3   252.0  1.25  16.0  7.0000  101.00  13.0   4.0  0.03  0.0004  41.0   6
# 4   227.0  1.28  23.0  0.0072  103.00  12.0   5.0  0.04  0.0004  33.0   8
# ..    ...   ...   ...     ...     ...   ...   ...   ...     ...   ...  ..
# 94  245.0  1.29  21.0  0.0055    0.15  15.0   3.0  0.05  0.0003  27.0   6
# 95  245.0  1.29  21.0  0.0055    0.15  15.0   3.0  0.05  0.0003  27.0   6
# 96  254.0  1.28  15.0  0.0044    0.15  15.0   4.0  0.03  0.0004  42.0   5
# 97  254.0  1.28  15.0  0.0044    0.15  15.0   4.0  0.03  0.0004  42.0   5
# 98  232.0  1.24  18.0  4.0000    0.15  12.0   1.0  0.03  0.0004  34.0   3
#
#      Pcu     Pca   Pni    Pmo      Pn  Dureza
# ...

# %%
x = dataset.iloc[:,:-1].values # DEPENDIENTES
#y = dataset.iloc[:,-1:].values # INDEPENDIENTES
y = dataset.iloc[:,-1:].values.flatten()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = SVC(kernel='linear',C=100)
model.fit(X_train, y_train)
# Out:
# SVC(C=200, kernel='linear')

# %%
model.score(x,y)
# Out:
# 0.5252525252525253

# %%
predictions = model.predict(x)

# %%
suma=0
for valor in range(len(predictions)):
    porcentaje=dataset["Dureza"][valor] - predictions[valor] 
    if(porcentaje==0):
        suma+=1
    print(dataset["Dureza"][valor],predictions[valor],)
print("Porcentaje:",suma/len(predictions))
# Out:
# 311 311
# 302 302
# 321 311
# 321 302
# 293 311
# 302 286
# 302 302
# 311 302
# 311 302
# 293 293
# 321 311
# 293 302
# 302 302
# 293 286
# 286 286
# 302 293
# 302 321
# 293 293
# 311 286
# 302 302
# 321 311
# 311 311
# 321 302
# 332 332
# 311 311
# 321 286
# 293 293
# 311 293
# 311 311
# 321 293
# 302 302
# 311 311
# 321 321
# 321 311
# 302 293
# 293 293
# 311 293
# 311 293
# 302 311
# 311 311
# 311 311
# 302 302
# 293 293
# 311 293
# 293 293
# 321 321
# 311 302
# 302 302
# 321 302
# 321 311
# 321 311
# 293 293
# 302 293
# 286 302
# 286 286
# 311 302
# 286 286
# 293 293
# 302 302
# 293 293
# 311 311
# 321 321
# 311 321
# 321 293
# 311 311
# 311 311
# 321 311
# 302 293
# 311 286
# 293 286
# 286 286
# 332 311
# 311 311
# 302 293
# 293 293
# 311 311
# 302 302
# 311 293
# 302 293
# 311 311
# 293 302
# 302 302
# 321 321
# 293 293
# 293 293
# 293 293
# 286 286
# 311 311
# 311 293
# 302 302
# 277 277
# 293 293
# 321 293
# 311 311
# 302 293
# 293 293
# 332 302
# 302 302
# 293 293
# ...
